# %%
import numpy as np
import matplotlib.pylab as plt

# %%
print('this is only test')
# Out:
# this is only test

# %%
# %matplotlib inline

# %%
number = np.pi*np.sqrt(2)
print(number)
test_numb = np.array(np.random.rand(10))
print(test_numb)
# Out:
# 4.44288293816
# [ 0.64734326  0.84685261  0.00345291  0.07144465  0.95164219  0.3668613
#   0.7796931   0.67790405  0.1392007   0.78059207]

# %%
plt.plot(np.array(np.random.rand(10)), test_numb)
